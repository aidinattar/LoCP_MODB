# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D

# %run plot.py

# %% [markdown]
# ### Read data

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000.dat'
fnamex='DATA/x_'+str0
fnamey='DATA/y_'+str0

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
N,L = len(x), len(x[0])

Show_data(x,L,"original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)

y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1.
# Out:
# data:  10000

# %% [markdown]
# ### Rescale data, split train/val.

# %%
#
#  FIRST PASSAGE:  DO NOT DO THIS --> FAILURE 
#
#remove average value of each sample from its values
xm = x.mean(axis=1)
for i in range(N):
    x[i] = x[i]-xm[i]

#
#  SECOND PASSAGE:  DO NOT DO THIS --> ALSO FAILURE 
#
#rescale (crude version, variance should be used)
x = x/400
    
Show_data(x,L,"rescaled data")

perc_train=0.8
N_train = int(perc_train*N)
x_train = x[:N_train]
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]
N_val = len(x_val)
print('N_train=',N_train,'  N_val=',N_val,'  L=',L,'  n_class=',n_class)

#x_train=x_train.astype("float32")
#y_train=y_train.astype("float32")
#x_val=x_val.astype("float32")
#y_val=y_val.astype("float32")

# Keras wants an additional dimension with a 1 at the end
x_train = x_train.reshape(x_train.shape[0], L, 1)
x_val =  x_val.reshape(x_val.shape[0], L, 1)
input_shape = (L, 1)
# Out:
# N_train= 8000   N_val= 2000   L= 60   n_class= 3

# %% [markdown]
# ## Convolutional NN

# %%
# ... LESSON ...
# reproducibility
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

from keras import regularizers, initializers

reg = regularizers.l2(.02) #it's the ridge
#reg = regularizers.l1(.1)

ini = keras.initializers.RandomNormal(mean=.0, stddev=.05, seed=None)

NCONV = 1
NF    = 5

#challenge: at most 600 tunable parameters
model = Sequential()
#
if NCONV==1:
    # ----- 2 -----
    model.add(Conv1D(filters=NF, kernel_size=11,
              kernel_initializer=ini,
              kernel_regularizer=reg, #bias_regularizer=, activity_regularizer=
              activation='relu',
              input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Conv1D(filters=5, kernel_size=7,
              activation='relu'))
    # !!add a pooling here!!
    model.add(Flatten())
    model.add(Dense(12, activation='relu'))
    model.add(Dropout(.2))
#
    model.add(Dense(n_class, activation='softmax')) #softmax!

print('---- Model', NCONV,'-----')
print(model.summary())

opt=tf.keras.optimizers.Adam()

# compile the model
# categorical crossentropy, 3 output nodes
model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
              optimizer=opt, metrics=['accuracy'])
# Out:
# ---- Model 1 -----
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 50, 5)             60
#
#  average_pooling1d_3 (Averag  (None, 10, 5)            0
#  ePooling1D)
#
#  conv1d_7 (Conv1D)           (None, 4, 5)              180
#
#  flatten_3 (Flatten)         (None, 20)                0
#
#  dense_6 (Dense)             (None, 12)                252
#
#  dropout_3 (Dropout)         (None, 12)                0
#
#  dense_7 (Dense)             (None, 3)                 39
#
# =================================================================
# Total params: 531
# Trainable params: 531
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.layers
# Out:
# [<keras.layers.convolutional.Conv1D at 0x7f2ef4459820>,
#  <keras.layers.pooling.AveragePooling1D at 0x7f2ef445e160>,
#  <keras.layers.convolutional.Conv1D at 0x7f2ef445e070>,
#  <keras.layers.core.flatten.Flatten at 0x7f2ef43f3130>,
#  <keras.layers.core.dense.Dense at 0x7f2ef43f3e80>,
#  <keras.layers.core.dropout.Dropout at 0x7f2ef43fadc0>,
#  <keras.layers.core.dense.Dense at 0x7f2ef4469880>]

# %%
def Show_weights(model,l=0,label="model"):
    c=['r','y','c','b','m']
    m=['o','s','D','<','>']
    ms=10
    
    w = model.layers[l].get_weights()[0]
    wT=w.T
    M=len(wT)
    b = model.layers[l].get_weights()[1]
    
    fig,AX=plt.subplots(1,2,figsize=(12,4.4))
    ax=AX[0]
    ax.axhline(0, c="k")
    ax.plot((0,))
    for i in range(M):
        ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
    ax.set_title(label+': filters of layer '+str(l))
    ax.set_xlabel('index')
    ax=AX[1]
    ax.axhline(0, c="k")
    for i in range(M):
        ax.plot((i),(b[i]),c=c[i],marker=m[i],label="filter "+str(i),markersize=ms)
    ax.set_title(label+': bias of layer '+str(l))
    ax.set_xlabel('filter nr')
    ax.set_xticks(np.arange(5))
    ax.legend()
    plt.show()
    
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...
# hyper parameters
#with small minibatch it does not converge!!

BATCH_SIZE = 250
EPOCHS     = 100

print('----- Model ',NCONV,'------\nFITTING.......')
fit = model.fit(x_train, y_train,batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                validation_data=(x_val, y_val),
                verbose=2, shuffle=True)
# try different level of regularization
# Out:
# ----- Model  1 ------
# FITTING.......
# Epoch 1/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3335 - 144ms/epoch - 4ms/step
# Epoch 2/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3313 - val_loss: 1.0986 - val_accuracy: 0.3335 - 131ms/epoch - 4ms/step
# Epoch 3/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3299 - val_loss: 1.0986 - val_accuracy: 0.3335 - 144ms/epoch - 5ms/step
# Epoch 4/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3234 - val_loss: 1.0986 - val_accuracy: 0.3335 - 139ms/epoch - 4ms/step
# Epoch 5/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3239 - val_loss: 1.0986 - val_accuracy: 0.3335 - 153ms/epoch - 5ms/step
# Epoch 6/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3234 - val_loss: 1.0986 - val_accuracy: 0.3330 - 169ms/epoch - 5ms/step
# Epoch 7/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 168ms/epoch - 5ms/step
# Epoch 8/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3288 - val_loss: 1.0986 - val_accuracy: 0.3330 - 156ms/epoch - 5ms/step
# Epoch 9/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3216 - val_loss: 1.0986 - val_accuracy: 0.3330 - 158ms/epoch - 5ms/step
# Epoch 10/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3268 - val_loss: 1.0986 - val_accuracy: 0.3335 - 157ms/epoch - 5ms/step
# Epoch 11/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3290 - val_loss: 1.0986 - val_accuracy: 0.3330 - 152ms/epoch - 5ms/step
# Epoch 12/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3310 - val_loss: 1.0986 - val_accuracy: 0.3335 - 137ms/epoch - 4ms/step
# Epoch 13/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3248 - val_loss: 1.0986 - val_accuracy: 0.3335 - 137ms/epoch - 4ms/step
# Epoch 14/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3335 - 135ms/epoch - 4ms/step
# Epoch 15/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3271 - val_loss: 1.0986 - val_accuracy: 0.3335 - 129ms/epoch - 4ms/step
# Epoch 16/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3301 - val_loss: 1.0986 - val_accuracy: 0.3335 - 123ms/epoch - 4ms/step
# Epoch 17/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3231 - val_loss: 1.0986 - val_accuracy: 0.3335 - 122ms/epoch - 4ms/step
# Epoch 18/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3262 - val_loss: 1.0986 - val_accuracy: 0.3335 - 120ms/epoch - 4ms/step
# Epoch 19/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3285 - val_loss: 1.0986 - val_accuracy: 0.3335 - 124ms/epoch - 4ms/step
# Epoch 20/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3255 - val_loss: 1.0986 - val_accuracy: 0.3335 - 124ms/epoch - 4ms/step
# Epoch 21/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3301 - val_loss: 1.0986 - val_accuracy: 0.3330 - 120ms/epoch - 4ms/step
# Epoch 22/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 127ms/epoch - 4ms/step
# Epoch 23/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 122ms/epoch - 4ms/step
# Epoch 24/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3276 - val_loss: 1.0986 - val_accuracy: 0.3335 - 124ms/epoch - 4ms/step
# Epoch 25/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3294 - val_loss: 1.0986 - val_accuracy: 0.3330 - 125ms/epoch - 4ms/step
# Epoch 26/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 123ms/epoch - 4ms/step
# Epoch 27/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3290 - val_loss: 1.0986 - val_accuracy: 0.3335 - 122ms/epoch - 4ms/step
# Epoch 28/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3313 - val_loss: 1.0986 - val_accuracy: 0.3330 - 125ms/epoch - 4ms/step
# Epoch 29/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3254 - val_loss: 1.0986 - val_accuracy: 0.3335 - 124ms/epoch - 4ms/step
# Epoch 30/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3273 - val_loss: 1.0986 - val_accuracy: 0.3330 - 123ms/epoch - 4ms/step
# Epoch 31/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3285 - val_loss: 1.0986 - val_accuracy: 0.3335 - 123ms/epoch - 4ms/step
# Epoch 32/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3335 - 119ms/epoch - 4ms/step
# Epoch 33/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3262 - val_loss: 1.0986 - val_accuracy: 0.3335 - 123ms/epoch - 4ms/step
# Epoch 34/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3309 - val_loss: 1.0986 - val_accuracy: 0.3330 - 119ms/epoch - 4ms/step
# Epoch 35/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3277 - val_loss: 1.0986 - val_accuracy: 0.3335 - 123ms/epoch - 4ms/step
# Epoch 36/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3264 - val_loss: 1.0986 - val_accuracy: 0.3330 - 130ms/epoch - 4ms/step
# Epoch 37/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3313 - val_loss: 1.0986 - val_accuracy: 0.3335 - 140ms/epoch - 4ms/step
# Epoch 38/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3256 - val_loss: 1.0986 - val_accuracy: 0.3335 - 125ms/epoch - 4ms/step
# Epoch 39/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3290 - val_loss: 1.0986 - val_accuracy: 0.3330 - 146ms/epoch - 5ms/step
# Epoch 40/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3311 - val_loss: 1.0986 - val_accuracy: 0.3335 - 150ms/epoch - 5ms/step
# Epoch 41/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3268 - val_loss: 1.0986 - val_accuracy: 0.3335 - 144ms/epoch - 4ms/step
# Epoch 42/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3294 - val_loss: 1.0986 - val_accuracy: 0.3330 - 135ms/epoch - 4ms/step
# Epoch 43/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3318 - val_loss: 1.0986 - val_accuracy: 0.3335 - 144ms/epoch - 4ms/step
# Epoch 44/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3264 - val_loss: 1.0986 - val_accuracy: 0.3335 - 173ms/epoch - 5ms/step
# Epoch 45/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3335 - 153ms/epoch - 5ms/step
# Epoch 46/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3335 - 137ms/epoch - 4ms/step
# Epoch 47/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3261 - val_loss: 1.0986 - val_accuracy: 0.3330 - 135ms/epoch - 4ms/step
# Epoch 48/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3224 - val_loss: 1.0986 - val_accuracy: 0.3335 - 132ms/epoch - 4ms/step
# Epoch 49/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3324 - val_loss: 1.0986 - val_accuracy: 0.3335 - 120ms/epoch - 4ms/step
# Epoch 50/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3304 - val_loss: 1.0986 - val_accuracy: 0.3330 - 122ms/epoch - 4ms/step
# Epoch 51/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 122ms/epoch - 4ms/step
# Epoch 52/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3338 - val_loss: 1.0986 - val_accuracy: 0.3335 - 120ms/epoch - 4ms/step
# Epoch 53/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3335 - 127ms/epoch - 4ms/step
# Epoch 54/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3306 - val_loss: 1.0986 - val_accuracy: 0.3335 - 127ms/epoch - 4ms/step
# Epoch 55/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3279 - val_loss: 1.0986 - val_accuracy: 0.3335 - 121ms/epoch - 4ms/step
# Epoch 56/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3306 - val_loss: 1.0986 - val_accuracy: 0.3330 - 124ms/epoch - 4ms/step
# Epoch 57/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 133ms/epoch - 4ms/step
# Epoch 58/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3219 - val_loss: 1.0986 - val_accuracy: 0.3335 - 177ms/epoch - 6ms/step
# Epoch 59/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3260 - val_loss: 1.0986 - val_accuracy: 0.3335 - 128ms/epoch - 4ms/step
# Epoch 60/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3231 - val_loss: 1.0986 - val_accuracy: 0.3330 - 130ms/epoch - 4ms/step
# Epoch 61/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3314 - val_loss: 1.0986 - val_accuracy: 0.3335 - 128ms/epoch - 4ms/step
# Epoch 62/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3204 - val_loss: 1.0986 - val_accuracy: 0.3335 - 128ms/epoch - 4ms/step
# Epoch 63/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3274 - val_loss: 1.0986 - val_accuracy: 0.3335 - 124ms/epoch - 4ms/step
# Epoch 64/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3302 - val_loss: 1.0986 - val_accuracy: 0.3330 - 123ms/epoch - 4ms/step
# Epoch 65/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3240 - val_loss: 1.0986 - val_accuracy: 0.3335 - 128ms/epoch - 4ms/step
# Epoch 66/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3211 - val_loss: 1.0986 - val_accuracy: 0.3335 - 121ms/epoch - 4ms/step
# Epoch 67/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3220 - val_loss: 1.0986 - val_accuracy: 0.3330 - 119ms/epoch - 4ms/step
# Epoch 68/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 120ms/epoch - 4ms/step
# Epoch 69/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3293 - val_loss: 1.0986 - val_accuracy: 0.3335 - 121ms/epoch - 4ms/step
# Epoch 70/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3271 - val_loss: 1.0986 - val_accuracy: 0.3335 - 120ms/epoch - 4ms/step
# Epoch 71/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3273 - val_loss: 1.0986 - val_accuracy: 0.3335 - 122ms/epoch - 4ms/step
# Epoch 72/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3306 - val_loss: 1.0986 - val_accuracy: 0.3330 - 121ms/epoch - 4ms/step
# Epoch 73/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 154ms/epoch - 5ms/step
# Epoch 74/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3281 - val_loss: 1.0986 - val_accuracy: 0.3335 - 120ms/epoch - 4ms/step
# Epoch 75/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3276 - val_loss: 1.0986 - val_accuracy: 0.3335 - 120ms/epoch - 4ms/step
# Epoch 76/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3236 - val_loss: 1.0986 - val_accuracy: 0.3335 - 123ms/epoch - 4ms/step
# Epoch 77/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3335 - 121ms/epoch - 4ms/step
# Epoch 78/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3274 - val_loss: 1.0986 - val_accuracy: 0.3335 - 120ms/epoch - 4ms/step
# Epoch 79/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3216 - val_loss: 1.0986 - val_accuracy: 0.3335 - 153ms/epoch - 5ms/step
# Epoch 80/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3304 - val_loss: 1.0986 - val_accuracy: 0.3335 - 140ms/epoch - 4ms/step
# Epoch 81/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3266 - val_loss: 1.0986 - val_accuracy: 0.3330 - 177ms/epoch - 6ms/step
# Epoch 82/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3320 - val_loss: 1.0986 - val_accuracy: 0.3335 - 226ms/epoch - 7ms/step
# Epoch 83/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3284 - val_loss: 1.0986 - val_accuracy: 0.3330 - 250ms/epoch - 8ms/step
# Epoch 84/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3229 - val_loss: 1.0986 - val_accuracy: 0.3335 - 214ms/epoch - 7ms/step
# Epoch 85/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3305 - val_loss: 1.0986 - val_accuracy: 0.3335 - 223ms/epoch - 7ms/step
# Epoch 86/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3296 - val_loss: 1.0986 - val_accuracy: 0.3330 - 156ms/epoch - 5ms/step
# Epoch 87/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3300 - val_loss: 1.0986 - val_accuracy: 0.3335 - 133ms/epoch - 4ms/step
# Epoch 88/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3221 - val_loss: 1.0986 - val_accuracy: 0.3335 - 139ms/epoch - 4ms/step
# Epoch 89/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3230 - val_loss: 1.0986 - val_accuracy: 0.3330 - 143ms/epoch - 4ms/step
# Epoch 90/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3285 - val_loss: 1.0986 - val_accuracy: 0.3335 - 132ms/epoch - 4ms/step
# Epoch 91/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3298 - val_loss: 1.0986 - val_accuracy: 0.3330 - 137ms/epoch - 4ms/step
# Epoch 92/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 134ms/epoch - 4ms/step
# Epoch 93/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3301 - val_loss: 1.0986 - val_accuracy: 0.3335 - 130ms/epoch - 4ms/step
# Epoch 94/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3271 - val_loss: 1.0986 - val_accuracy: 0.3330 - 162ms/epoch - 5ms/step
# Epoch 95/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3260 - val_loss: 1.0986 - val_accuracy: 0.3335 - 156ms/epoch - 5ms/step
# Epoch 96/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3261 - val_loss: 1.0986 - val_accuracy: 0.3330 - 170ms/epoch - 5ms/step
# Epoch 97/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3246 - val_loss: 1.0986 - val_accuracy: 0.3335 - 184ms/epoch - 6ms/step
# Epoch 98/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3307 - val_loss: 1.0986 - val_accuracy: 0.3335 - 200ms/epoch - 6ms/step
# Epoch 99/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3195 - val_loss: 1.0986 - val_accuracy: 0.3335 - 150ms/epoch - 5ms/step
# Epoch 100/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3314 - val_loss: 1.0986 - val_accuracy: 0.3330 - 136ms/epoch - 4ms/step

# %%
def Show_history(fit):
    fig,AX=plt.subplots(1,2,figsize=(12,5.))
    ax=AX[0]
    ax.plot(fit.history['accuracy'],"b",label="train")
    ax.plot(fit.history['val_accuracy'],"r--",label="valid.")
    ax.plot((0,EPOCHS),(1/3,1/3),":",c="gray",label="random choice")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1])
    ax.legend()
    ax=AX[1]
    ax.plot(fit.history['loss'],"b",label="train")
    ax.plot(fit.history['val_loss'],"r--",label="valid.")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.set_ylim([0, 1.05*np.max(fit.history['loss'])])
    ax.legend()
    plt.show()
Show_history(fit)
Show_weights(model,0)
Show_weights(model,2)

# %%
# ...LESSON ...
reg2 = regularizers.l2(2.0)
model2 = keras.models.clone_model(model)
model2.layers[0].kernel_regularizer = reg2
model2.layers[1].kernel_regularizer = reg2
model2.layers[2].kernel_regularizer = reg2
model2.compile(loss=tf.keras.losses.CategoricalCrossentropy(), optimizer=opt,metrics=['accuracy'])

# ...LESSON ...
# hyper parameters
#with small minibatch it does not converge!!

BATCH_SIZE = 250
EPOCHS     = 100

print('----- Model ',NCONV,'------\nFITTING.......')
fit2 = model2.fit(x_train, y_train,batch_size=BATCH_SIZE,
                  epochs=EPOCHS,
                  validation_data=(x_val, y_val),
                  verbose=2, shuffle=True)
# Out:
# ----- Model  1 ------
# FITTING.......
# Epoch 1/100
# 32/32 - 1s - loss: 1.0995 - accuracy: 0.3240 - val_loss: 1.0987 - val_accuracy: 0.3335 - 679ms/epoch - 21ms/step
# Epoch 2/100
# 32/32 - 0s - loss: 1.0988 - accuracy: 0.3332 - val_loss: 1.0986 - val_accuracy: 0.3335 - 127ms/epoch - 4ms/step
# Epoch 3/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3313 - val_loss: 1.0986 - val_accuracy: 0.3330 - 129ms/epoch - 4ms/step
# Epoch 4/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 133ms/epoch - 4ms/step
# Epoch 5/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3295 - val_loss: 1.0986 - val_accuracy: 0.3335 - 135ms/epoch - 4ms/step
# Epoch 6/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3199 - val_loss: 1.0986 - val_accuracy: 0.3330 - 131ms/epoch - 4ms/step
# Epoch 7/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3223 - val_loss: 1.0986 - val_accuracy: 0.3335 - 129ms/epoch - 4ms/step
# Epoch 8/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3311 - val_loss: 1.0986 - val_accuracy: 0.3330 - 134ms/epoch - 4ms/step
# Epoch 9/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3219 - val_loss: 1.0986 - val_accuracy: 0.3330 - 143ms/epoch - 4ms/step
# Epoch 10/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3279 - val_loss: 1.0986 - val_accuracy: 0.3335 - 137ms/epoch - 4ms/step
# Epoch 11/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3305 - val_loss: 1.0986 - val_accuracy: 0.3330 - 201ms/epoch - 6ms/step
# Epoch 12/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3310 - val_loss: 1.0986 - val_accuracy: 0.3335 - 182ms/epoch - 6ms/step
# Epoch 13/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3257 - val_loss: 1.0986 - val_accuracy: 0.3335 - 158ms/epoch - 5ms/step
# Epoch 14/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3322 - val_loss: 1.0986 - val_accuracy: 0.3335 - 159ms/epoch - 5ms/step
# Epoch 15/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3252 - val_loss: 1.0986 - val_accuracy: 0.3330 - 138ms/epoch - 4ms/step
# Epoch 16/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3309 - val_loss: 1.0986 - val_accuracy: 0.3330 - 133ms/epoch - 4ms/step
# Epoch 17/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3273 - val_loss: 1.0986 - val_accuracy: 0.3335 - 129ms/epoch - 4ms/step
# Epoch 18/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3251 - val_loss: 1.0986 - val_accuracy: 0.3330 - 130ms/epoch - 4ms/step
# Epoch 19/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3276 - val_loss: 1.0986 - val_accuracy: 0.3335 - 130ms/epoch - 4ms/step
# Epoch 20/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3255 - val_loss: 1.0986 - val_accuracy: 0.3335 - 127ms/epoch - 4ms/step
# Epoch 21/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3282 - val_loss: 1.0986 - val_accuracy: 0.3335 - 133ms/epoch - 4ms/step
# Epoch 22/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3304 - val_loss: 1.0986 - val_accuracy: 0.3330 - 128ms/epoch - 4ms/step
# Epoch 23/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3281 - val_loss: 1.0986 - val_accuracy: 0.3330 - 130ms/epoch - 4ms/step
# Epoch 24/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3302 - val_loss: 1.0986 - val_accuracy: 0.3335 - 126ms/epoch - 4ms/step
# Epoch 25/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3294 - val_loss: 1.0986 - val_accuracy: 0.3330 - 124ms/epoch - 4ms/step
# Epoch 26/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 193ms/epoch - 6ms/step
# Epoch 27/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3289 - val_loss: 1.0986 - val_accuracy: 0.3335 - 132ms/epoch - 4ms/step
# Epoch 28/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3310 - val_loss: 1.0986 - val_accuracy: 0.3335 - 130ms/epoch - 4ms/step
# Epoch 29/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3234 - val_loss: 1.0986 - val_accuracy: 0.3335 - 131ms/epoch - 4ms/step
# Epoch 30/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3293 - val_loss: 1.0986 - val_accuracy: 0.3330 - 124ms/epoch - 4ms/step
# Epoch 31/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3285 - val_loss: 1.0986 - val_accuracy: 0.3335 - 123ms/epoch - 4ms/step
# Epoch 32/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3335 - 122ms/epoch - 4ms/step
# Epoch 33/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3293 - val_loss: 1.0986 - val_accuracy: 0.3335 - 126ms/epoch - 4ms/step
# Epoch 34/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3311 - val_loss: 1.0986 - val_accuracy: 0.3330 - 123ms/epoch - 4ms/step
# Epoch 35/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3310 - val_loss: 1.0986 - val_accuracy: 0.3335 - 127ms/epoch - 4ms/step
# Epoch 36/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3251 - val_loss: 1.0986 - val_accuracy: 0.3330 - 128ms/epoch - 4ms/step
# Epoch 37/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3313 - val_loss: 1.0986 - val_accuracy: 0.3335 - 124ms/epoch - 4ms/step
# Epoch 38/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3221 - val_loss: 1.0986 - val_accuracy: 0.3335 - 126ms/epoch - 4ms/step
# Epoch 39/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3290 - val_loss: 1.0986 - val_accuracy: 0.3330 - 123ms/epoch - 4ms/step
# Epoch 40/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3311 - val_loss: 1.0986 - val_accuracy: 0.3335 - 130ms/epoch - 4ms/step
# Epoch 41/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3268 - val_loss: 1.0986 - val_accuracy: 0.3335 - 124ms/epoch - 4ms/step
# Epoch 42/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3294 - val_loss: 1.0986 - val_accuracy: 0.3330 - 124ms/epoch - 4ms/step
# Epoch 43/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3327 - val_loss: 1.0986 - val_accuracy: 0.3335 - 124ms/epoch - 4ms/step
# Epoch 44/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3281 - val_loss: 1.0986 - val_accuracy: 0.3335 - 123ms/epoch - 4ms/step
# Epoch 45/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3335 - 126ms/epoch - 4ms/step
# Epoch 46/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3335 - 123ms/epoch - 4ms/step
# Epoch 47/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3261 - val_loss: 1.0986 - val_accuracy: 0.3330 - 125ms/epoch - 4ms/step
# Epoch 48/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3229 - val_loss: 1.0986 - val_accuracy: 0.3335 - 124ms/epoch - 4ms/step
# Epoch 49/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3324 - val_loss: 1.0986 - val_accuracy: 0.3335 - 139ms/epoch - 4ms/step
# Epoch 50/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3304 - val_loss: 1.0986 - val_accuracy: 0.3330 - 165ms/epoch - 5ms/step
# Epoch 51/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 159ms/epoch - 5ms/step
# Epoch 52/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3338 - val_loss: 1.0986 - val_accuracy: 0.3335 - 149ms/epoch - 5ms/step
# Epoch 53/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3335 - 149ms/epoch - 5ms/step
# Epoch 54/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3306 - val_loss: 1.0986 - val_accuracy: 0.3335 - 164ms/epoch - 5ms/step
# Epoch 55/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3269 - val_loss: 1.0986 - val_accuracy: 0.3335 - 146ms/epoch - 5ms/step
# Epoch 56/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3306 - val_loss: 1.0986 - val_accuracy: 0.3330 - 138ms/epoch - 4ms/step
# Epoch 57/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 141ms/epoch - 4ms/step
# Epoch 58/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3219 - val_loss: 1.0986 - val_accuracy: 0.3335 - 142ms/epoch - 4ms/step
# Epoch 59/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3260 - val_loss: 1.0986 - val_accuracy: 0.3335 - 134ms/epoch - 4ms/step
# Epoch 60/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3243 - val_loss: 1.0986 - val_accuracy: 0.3330 - 130ms/epoch - 4ms/step
# Epoch 61/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3295 - val_loss: 1.0986 - val_accuracy: 0.3335 - 140ms/epoch - 4ms/step
# Epoch 62/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3212 - val_loss: 1.0986 - val_accuracy: 0.3335 - 137ms/epoch - 4ms/step
# Epoch 63/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3274 - val_loss: 1.0986 - val_accuracy: 0.3335 - 137ms/epoch - 4ms/step
# Epoch 64/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3302 - val_loss: 1.0986 - val_accuracy: 0.3330 - 153ms/epoch - 5ms/step
# Epoch 65/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3240 - val_loss: 1.0986 - val_accuracy: 0.3335 - 140ms/epoch - 4ms/step
# Epoch 66/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3211 - val_loss: 1.0986 - val_accuracy: 0.3335 - 190ms/epoch - 6ms/step
# Epoch 67/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3220 - val_loss: 1.0986 - val_accuracy: 0.3330 - 166ms/epoch - 5ms/step
# Epoch 68/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 138ms/epoch - 4ms/step
# Epoch 69/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3293 - val_loss: 1.0986 - val_accuracy: 0.3335 - 148ms/epoch - 5ms/step
# Epoch 70/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3271 - val_loss: 1.0986 - val_accuracy: 0.3335 - 150ms/epoch - 5ms/step
# Epoch 71/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3273 - val_loss: 1.0986 - val_accuracy: 0.3335 - 135ms/epoch - 4ms/step
# Epoch 72/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3306 - val_loss: 1.0986 - val_accuracy: 0.3330 - 139ms/epoch - 4ms/step
# Epoch 73/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 145ms/epoch - 5ms/step
# Epoch 74/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3290 - val_loss: 1.0986 - val_accuracy: 0.3335 - 132ms/epoch - 4ms/step
# Epoch 75/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3276 - val_loss: 1.0986 - val_accuracy: 0.3335 - 137ms/epoch - 4ms/step
# Epoch 76/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3236 - val_loss: 1.0986 - val_accuracy: 0.3335 - 136ms/epoch - 4ms/step
# Epoch 77/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3335 - 150ms/epoch - 5ms/step
# Epoch 78/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3274 - val_loss: 1.0986 - val_accuracy: 0.3335 - 166ms/epoch - 5ms/step
# Epoch 79/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3216 - val_loss: 1.0986 - val_accuracy: 0.3335 - 141ms/epoch - 4ms/step
# Epoch 80/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3304 - val_loss: 1.0986 - val_accuracy: 0.3335 - 141ms/epoch - 4ms/step
# Epoch 81/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3266 - val_loss: 1.0986 - val_accuracy: 0.3330 - 142ms/epoch - 4ms/step
# Epoch 82/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3320 - val_loss: 1.0986 - val_accuracy: 0.3335 - 126ms/epoch - 4ms/step
# Epoch 83/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3284 - val_loss: 1.0986 - val_accuracy: 0.3330 - 126ms/epoch - 4ms/step
# Epoch 84/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3251 - val_loss: 1.0986 - val_accuracy: 0.3335 - 124ms/epoch - 4ms/step
# Epoch 85/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3305 - val_loss: 1.0986 - val_accuracy: 0.3335 - 121ms/epoch - 4ms/step
# Epoch 86/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3296 - val_loss: 1.0986 - val_accuracy: 0.3330 - 188ms/epoch - 6ms/step
# Epoch 87/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3300 - val_loss: 1.0986 - val_accuracy: 0.3335 - 131ms/epoch - 4ms/step
# Epoch 88/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3186 - val_loss: 1.0986 - val_accuracy: 0.3335 - 125ms/epoch - 4ms/step
# Epoch 89/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3230 - val_loss: 1.0986 - val_accuracy: 0.3330 - 122ms/epoch - 4ms/step
# Epoch 90/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3285 - val_loss: 1.0986 - val_accuracy: 0.3335 - 126ms/epoch - 4ms/step
# Epoch 91/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3298 - val_loss: 1.0986 - val_accuracy: 0.3330 - 122ms/epoch - 4ms/step
# Epoch 92/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3330 - 123ms/epoch - 4ms/step
# Epoch 93/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3301 - val_loss: 1.0986 - val_accuracy: 0.3335 - 122ms/epoch - 4ms/step
# Epoch 94/100
# 32/32 - 0s - loss: 1.0987 - accuracy: 0.3271 - val_loss: 1.0986 - val_accuracy: 0.3330 - 126ms/epoch - 4ms/step
# Epoch 95/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3260 - val_loss: 1.0986 - val_accuracy: 0.3335 - 122ms/epoch - 4ms/step
# Epoch 96/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3261 - val_loss: 1.0986 - val_accuracy: 0.3330 - 124ms/epoch - 4ms/step
# Epoch 97/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3246 - val_loss: 1.0986 - val_accuracy: 0.3335 - 125ms/epoch - 4ms/step
# Epoch 98/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3307 - val_loss: 1.0986 - val_accuracy: 0.3335 - 123ms/epoch - 4ms/step
# Epoch 99/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3195 - val_loss: 1.0986 - val_accuracy: 0.3335 - 123ms/epoch - 4ms/step
# Epoch 100/100
# 32/32 - 0s - loss: 1.0986 - accuracy: 0.3314 - val_loss: 1.0986 - val_accuracy: 0.3330 - 124ms/epoch - 4ms/step

# %%
Show_history(fit)
Show_history(fit2)
Show_weights(model2,0,label="model2")
Show_weights(model2,2,label="model2")

# %%
import pandas as pd
from scipy import stats

import seaborn 
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn import preprocessing

LABELS = ["absent","positive","negative"]
cmap="GnBu"

def show_confusion_matrix(validations, predictions):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    seaborn.heatmap(matrix,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d',
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_val = model.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val)

#print(classification_report(max_y_val, max_y_pred_val))
