# %%
import matplotlib.pyplot as plt
import numpy as np

# number of data
N=4000
# size of each sample
L=2
# box size
B=100

# !mkdir DATA
# Out:
# mkdir: cannot create directory ‘DATA’: File exists

# %%
# %run nonlinear_function.py # to run an external program

TYPE=2

# random seed for reproducibility
np.random.seed(12345)
print(np.random.randint(0,10),np.random.randint(0,10),np.random.randint(0,10))

x,y = (np.random.random((N,2))-0.5)*B, np.zeros(N)
for i in range(N):
    # label data according to a nonlinear function "f"
    y[i] = f(x[i],TYPE)

plt.figure(figsize=(8,5))
plt.scatter(x[:,0],x[:,1],c=y)
plt.show

np.savetxt(filename(  "data_diff",TYPE),x)
np.savetxt(filename("labels_diff",TYPE),y,fmt="%d")
#plt.savefig('figures/set1.pdf', bbox_inches='tight')
# Out:
# 2 5 1

# %%
#training data
# %run nonlinear_function.py # to run an external program
perc_train = 0.8

#keras works with numpy arrays: just use them from the start
TYPE = 1
x = np.loadtxt(filename('data', TYPE), delimiter=' ')
y = np.loadtxt(filename('labels', TYPE), delimiter=' ')
N = len(x)
TYPE = 2
x_alt = np.loadtxt(filename('data_diff', TYPE), delimiter=' ')
y_alt = np.loadtxt(filename('labels_diff', TYPE), delimiter=' ')
N_alt = len(x_alt)



#dim of a sample
L = len(x[0])
L_red = len(x_alt[0])


N_train     = int( perc_train * N     )
N_train_alt = int( perc_train * N_alt )

(x_train, y_train) = (x[:N_train],y[:N_train])
(x_valid, y_valid) = (x[N_train:],y[N_train:])
print("Train:",len(x_train),"\t Validation:",len(x_valid))

(x_train_alt, y_train_alt) = (x_alt[:N_train_alt],y[:N_train_alt])
(x_valid_alt, y_valid_alt) = (x_alt[N_train_alt:],y[N_train_alt:])

fig, ax = plt.subplots(ncols = 2, figsize = (22.5,11))
ax[1].scatter(x_alt[:,0],x_alt[:,1],c=y_alt)
ax[0].scatter(x    [:,0],x    [:,1],c=y    )
plt.show()

fig.savefig('figures/set.pdf')
# Out:
# Train: 3200 	 Validation: 800

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1cb9264e-65a5-431d-a980-16667908489e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
