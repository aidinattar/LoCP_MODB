# %%
import matplotlib.pyplot as plt
import numpy as np

# number of data
N=8000
# size of each sample
L=2
# box size
B=100

# !mkdir DATA
# Out:
# mkdir: cannot create directory ‘DATA’: File exists

# %%
# %run nonlinear_function.py # to run an external program

TYPE=2

# random seed for reproducibility
np.random.seed(12345)
print(np.random.randint(0,10),np.random.randint(0,10),np.random.randint(0,10))

x,y = (np.random.random((N,2))-0.5)*B, np.zeros(N)
for i in range(N):
    # label data according to a nonlinear function "f"
    y[i] = f(x[i],TYPE)

plt.figure(figsize=(8,5))
plt.scatter(x[:,0],x[:,1],c=y)
plt.show

np.savetxt(filename(  "data_diff_inc",TYPE),x)
np.savetxt(filename("labels_diff_inc",TYPE),y,fmt="%d")
#plt.savefig('figures/set1.pdf', bbox_inches='tight')
# Out:
# 2 5 1

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1cb9264e-65a5-431d-a980-16667908489e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
